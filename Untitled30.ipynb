# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('C:/Users/GAURAV/Downloads/Cars Dataset/'):
        print(os.path.join(dirname))
# Out:
# C:/Users/GAURAV/Downloads/Cars Dataset/
# C:/Users/GAURAV/Downloads/Cars Dataset/test
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Audi
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Chevrolet
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Ford
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Hyundai Creta
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Mahindra Scorpio
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Mercedes
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Rolls Royce
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Swift
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Tata Safari
# C:/Users/GAURAV/Downloads/Cars Dataset/test\Toyota Innova
# C:/Users/GAURAV/Downloads/Cars Dataset/train
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Audi
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Chevrolet
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Ford
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Hyundai Creta
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Mahindra Scorpio
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Mercedes
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Rolls Royce
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Swift
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Tata Safari
# C:/Users/GAURAV/Downloads/Cars Dataset/train\Toyota Innova

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Convolution2D,MaxPooling2D,Flatten #action detectionimport tensorflow
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import HTML

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
IMAGE_SIZE = 128

train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        horizontal_flip=True
)
train_generator = train_datagen.flow_from_directory(
        'C:/Users/GAURAV/Downloads/Cars Dataset/train',
        target_size=(IMAGE_SIZE,IMAGE_SIZE),
        class_mode="sparse",
)
# Out:
# Found 3210 images belonging to 10 classes.

# %%
count=0
for image_batch, label_batch in train_generator:
#     print(label_batch)
    print(image_batch[0])
    break
# Out:
# [[[0.75683963 0.63866544 0.46217167]
#   [0.76097345 0.63689375 0.46453384]
#   [0.7648206  0.6354662  0.46706805]
#   ...
#   [0.4204265  0.37935787 0.22800976]
#   [0.4121593  0.37754965 0.23784678]
#   [0.43302348 0.41564    0.22018132]]
#
#  [[0.739413   0.6427427  0.45745462]
#   [0.7382319  0.6451049  0.45391136]
#   [0.73796934 0.64675266 0.45138863]
#   ...
#   [0.42219812 0.3799484  0.24336398]
#   [0.40979713 0.37695912 0.23430349]
#   [0.4383384  0.42390764 0.21781912]]
#
#  [[0.7461324  0.6251667  0.484853  ]
#   [0.7455419  0.62871    0.47894755]
#   [0.7448045  0.63195974 0.47362915]
#   ...
#   [0.42294234 0.3802454  0.25402132]
#   [0.40876168 0.3778994  0.23096433]
#   [0.4457748  0.4341821  0.21763577]]
#
#  ...
#
#  [[0.32059392 0.36765274 0.43039784]
#   [0.2375394  0.2845982  0.34734333]
#   [0.291916   0.33897483 0.40171993]
#   ...
#   [0.21690193 0.25219604 0.3110196 ]
#   [0.21487111 0.25016522 0.30898875]
#   [0.21900493 0.25429904 0.31312257]]
#
#  [[0.30983806 0.35689688 0.41964197]
#   [0.24262148 0.2896803  0.3524254 ]
#   [0.29323012 0.34028894 0.40303403]
#   ...
#   [0.347897   0.3831911  0.44201466]
#   [0.3319225  0.36721665 0.42604017]
#   [0.31125337 0.34654748 0.40537104]]
#
#  [[0.29684603 0.34390485 0.40664995]
#   [0.25147966 0.2985385  0.3612836 ]
#   [0.29204902 0.33910784 0.40185294]
#   ...
#   [0.30536634 0.34066045 0.39948398]
#   [0.31174767 0.3470418  0.4058653 ]
#   [0.31824368 0.35353783 0.41236135]]]

# %%
class_names = list(train_generator.class_indices.keys())
class_names
# Out:
# ['Audi',
#  'Chevrolet',
#  'Ford',
#  'Hyundai Creta',
#  'Mahindra Scorpio',
#  'Mercedes',
#  'Rolls Royce',
#  'Swift',
#  'Tata Safari',
#  'Toyota Innova']

# %%
test_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        horizontal_flip=True)

test_generator = test_datagen.flow_from_directory(
        'C:/Users/GAURAV/Downloads/Cars Dataset/test',
        target_size=(IMAGE_SIZE,IMAGE_SIZE),
        class_mode="sparse"
)
# Out:
# Found 1264 images belonging to 10 classes.

# %%
for image_batch, label_batch in test_generator:
    print(image_batch[0])
    break
# Out:
# [[[0.62409973 0.6730124  0.76577526]
#   [0.6684126  0.7184459  0.79579705]
#   [0.62224805 0.6879998  0.81273204]
#   ...
#   [0.9960785  0.9960785  0.9960785 ]
#   [0.9960785  0.9960785  0.9960785 ]
#   [0.9960785  0.9960785  0.9960785 ]]
#
#  [[0.6344348  0.6841425  0.7796879 ]
#   [0.65927005 0.7089058  0.7874495 ]
#   [0.63139063 0.69515485 0.81312954]
#   ...
#   [0.9960785  0.9960785  0.9960785 ]
#   [0.9960785  0.9960785  0.9960785 ]
#   [0.9960785  0.9960785  0.9960785 ]]
#
#  [[0.6447699  0.69527256 0.7936005 ]
#   [0.6501274  0.6993657  0.7791019 ]
#   [0.64053327 0.7023099  0.81352705]
#   ...
#   [0.9960785  0.9960785  0.9960785 ]
#   [0.9960785  0.9960785  0.9960785 ]
#   [0.9960785  0.9960785  0.9960785 ]]
#
#  ...
#
#  [[0.8080002  0.78839236 0.77662766]
#   [0.80323017 0.7836223  0.7718576 ]
#   [0.7984601  0.7788523  0.7670876 ]
#   ...
#   [0.90292925 0.8833214  0.8715567 ]
#   [0.905015   0.88540715 0.87364244]
#   [0.8992834  0.87967557 0.86791086]]
#
#  [[0.78675574 0.76809496 0.75633025]
#   [0.79271823 0.774455   0.7626903 ]
#   [0.7986808  0.78081506 0.76905036]
#   ...
#   [0.9009417  0.8813339  0.8695692 ]
#   [0.90700245 0.8873946  0.8756299 ]
#   [0.89809096 0.8784831  0.8667184 ]]
#
#  [[0.8322995  0.8166132  0.8048485 ]
#   [0.832697   0.8170107  0.805246  ]
#   [0.83309454 0.8174082  0.8056435 ]
#   ...
#   [0.8989543  0.87934643 0.8675817 ]
#   [0.90898997 0.8893821  0.8776174 ]
#   [0.89689845 0.8772906  0.8655259 ]]]

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D, Input

sz = 128

# Initializing the CNN
model = Sequential()

# Adding the Input layer
model.add(Input(shape=(sz, sz, 3)))

# First convolution layer and pooling
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

# Second convolution layer and pooling
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

# Third convolution layer and pooling
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

# Global average pooling instead of flattening
model.add(GlobalAveragePooling2D())

# Adding fully connected layers
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 126, 126, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 61, 61, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 119,562 (467.04 KB)
#  Trainable params: 119,114 (465.29 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=100
)
# Out:
# Epoch 1/100
# C:\Users\GAURAV\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 99s 861ms/step - accuracy: 0.1220 - loss: 2.4497 - val_accuracy: 0.1013 - val_loss: 2.3108
# Epoch 2/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 46s 447ms/step - accuracy: 0.1769 - loss: 2.2669 - val_accuracy: 0.1179 - val_loss: 2.3673
# Epoch 3/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 48s 471ms/step - accuracy: 0.2065 - loss: 2.2077 - val_accuracy: 0.0854 - val_loss: 2.4920
# Epoch 4/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 51s 491ms/step - accuracy: 0.2101 - loss: 2.1962 - val_accuracy: 0.1163 - val_loss: 2.2931
# Epoch 5/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 55s 537ms/step - accuracy: 0.2256 - loss: 2.1638 - val_accuracy: 0.1210 - val_loss: 2.2936
# Epoch 6/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 49s 468ms/step - accuracy: 0.2314 - loss: 2.1591 - val_accuracy: 0.1345 - val_loss: 2.2529
# Epoch 7/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 49s 472ms/step - accuracy: 0.2272 - loss: 2.1500 - val_accuracy: 0.1361 - val_loss: 2.2719
# Epoch 8/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 47s 455ms/step - accuracy: 0.2480 - loss: 2.1075 - val_accuracy: 0.1646 - val_loss: 2.1681
# Epoch 9/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 48s 467ms/step - accuracy: 0.2588 - loss: 2.1007 - val_accuracy: 0.2089 - val_loss: 2.1323
# Epoch 10/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 51s 496ms/step - accuracy: 0.2629 - loss: 2.0641 - val_accuracy: 0.1835 - val_loss: 2.1584
# Epoch 11/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 47s 457ms/step - accuracy: 0.2899 - loss: 2.0397 - val_accuracy: 0.1582 - val_loss: 2.3604
# Epoch 12/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 47s 459ms/step - accuracy: 0.3030 - loss: 1.9974 - val_accuracy: 0.2310 - val_loss: 2.4168
# Epoch 13/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 45s 439ms/step - accuracy: 0.2999 - loss: 1.9734 - val_accuracy: 0.2413 - val_loss: 2.3120
# Epoch 14/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 58s 569ms/step - accuracy: 0.3390 - loss: 1.9163 - val_accuracy: 0.2033 - val_loss: 2.1220
# Epoch 15/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 73s 699ms/step - accuracy: 0.3592 - loss: 1.8956 - val_accuracy: 0.1915 - val_loss: 2.3680
# Epoch 16/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━
100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.8495 - loss: 0.4059 - val_accuracy: 0.6748 - val_loss: 1.2268
# Epoch 88/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 46s 444ms/step - accuracy: 0.8281 - loss: 0.4736 - val_accuracy: 0.6938 - val_loss: 0.9900
# Epoch 89/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 45s 435ms/step - accuracy: 0.8493 - loss: 0.3996 - val_accuracy: 0.7373 - val_loss: 0.9124
# Epoch 90/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 46s 448ms/step - accuracy: 0.8529 - loss: 0.4258 - val_accuracy: 0.6938 - val_loss: 0.9945
# Epoch 91/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 47s 457ms/step - accuracy: 0.8674 - loss: 0.4023 - val_accuracy: 0.7334 - val_loss: 0.9098
# Epoch 92/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 44s 431ms/step - accuracy: 0.8552 - loss: 0.4148 - val_accuracy: 0.6155 - val_loss: 1.6205
# Epoch 93/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 45s 434ms/step - accuracy: 0.8504 - loss: 0.4149 - val_accuracy: 0.6930 - val_loss: 1.0363
# Epoch 94/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 46s 444ms/step - accuracy: 0.8498 - loss: 0.4136 - val_accuracy: 0.6566 - val_loss: 1.3082
# Epoch 95/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 44s 426ms/step - accuracy: 0.8619 - loss: 0.4254 - val_accuracy: 0.6677 - val_loss: 1.1610
# Epoch 96/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 46s 444ms/step - accuracy: 0.8691 - loss: 0.3679 - val_accuracy: 0.6677 - val_loss: 1.2139
# Epoch 97/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 48s 472ms/step - accuracy: 0.8600 - loss: 0.3875 - val_accuracy: 0.6962 - val_loss: 1.2033
# Epoch 98/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 47s 454ms/step - accuracy: 0.8521 - loss: 0.3913 - val_accuracy: 0.7342 - val_loss: 0.8562
# Epoch 99/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 45s 438ms/step - accuracy: 0.8704 - loss: 0.3542 - val_accuracy: 0.6598 - val_loss: 1.1377
# Epoch 100/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 48s 466ms/step - accuracy: 0.8847 - loss: 0.3224 - val_accuracy: 0.6432 - val_loss: 1.4554

# %%
scores = model.evaluate(test_generator)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.6439 - loss: 1.3654

# %%
scores
# Out:
# [1.3797473907470703, 0.6558544039726257]

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 100

# %%
history.history['loss'][:5]
# Out:
# [2.333526611328125,
#  2.2570791244506836,
#  2.2126080989837646,
#  2.1840779781341553,
#  2.173060178756714]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt
EPOCHS = 100

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_generator:
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
    break
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
